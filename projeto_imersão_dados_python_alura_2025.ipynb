# %% [markdown]
# <a href="https://colab.research.google.com/github/ClairtonZerwes/projeto-dados-python-2025-analise-tratamento/blob/main/projeto_imers%C3%A3o_dados_python_alura_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto Imersão Dados Python Alura 2025
#
# Clairton da Silva Zerwes
#
# Criciúma, 11 de Agosto de 2025

# %% [markdown]
# ## Aula 01 - Análise dos Dados com Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv')

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print(f"Número de Linhas: {linhas}")
print(f"Número de Colunas: {colunas}")
# Out:
# Número de Linhas: 133349
# Número de Colunas: 11

# %%
# Ou imprime o número de linhas e colunas sem atribuir a uma variável
print(f"Número de Linhas: {df.shape[0]}")
print(f"Número de Colunas: {df.shape[1]}")
# Out:
# Número de Linhas: 133349
# Número de Colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
dfbr = df.copy()
dfbr.columns = ['ano_trabalho', 'nivel_experiencia', 'tipo_emprego', 'titulo_cargo', 'salario', 'moeda_salario', 'salario_em_usd', 'residencia_empregado', 'taxa_remoto', 'localizacao_empresa', 'tamanho_empresa']
display(dfbr.head())
# Out:
#    ano_trabalho nivel_experiencia tipo_emprego        titulo_cargo  salario  \
# 0        2025.0                SE           FT  Solutions Engineer   214000
# 1        2025.0                SE           FT  Solutions Engineer   136000
# 2        2025.0                MI           FT       Data Engineer   158800
# 3        2025.0                MI           FT       Data Engineer   139200
# 4        2025.0                EN           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  taxa_remoto  \
# 0           USD          214000                   US          100
# 1           USD          136000                   US          100
# 2           USD          158800                   AU            0
# 3           USD          139200                   AU            0
# 4           USD           90000                   US            0
#
#   localizacao_empresa tamanho_empresa
# 0                  US               M
# ...

# %%
# Ou Renomear as colunas para uma variável array e depois atribuir para o df


renomear_colunas = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

print(renomear_colunas)
# Out:
# {'work_year': 'ano', 'experience_level': 'senioridade', 'employment_type': 'contrato', 'job_title': 'cargo', 'salary': 'salario', 'salary_currency': 'moeda', 'salary_in_usd': 'usd', 'employee_residence': 'residencia', 'remote_ratio': 'remoto', 'company_location': 'empresa', 'company_size': 'tamanho_empresa'}

# %%
# Atribuir as nova labesl nome da colunas para o data frame df
df.rename(columns=renomear_colunas, inplace=True)
df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["senioridade"].value_counts()
# Legenda de Senioridades SE = Senior | MI = Pleno | EN = Junior | EX = Executivo(CEO Level)
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Tipo de Contrato de Trabalho ["tipo_emprego"]
# FT = Full Time (Horário Integral, comercial aqui no Brasil)
# CT = Contato Trabalho por determinado período de tempo
# PT = Parcial Time (Meio Período)
# FL = FreeLance (Trabalho por projetos ou em deteminadas atividades)
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
# Tipo de Contrato de Trabalho ["tipo_emprego"]
"""
FT = Full Time (Horário Integral, comercial aqui no Brasil)
CT = Contato Trabalho por determinado período de tempo
PT = Parcial Time (Meio Período)
FL = FreeLance (Trabalho por projetos ou em deteminadas atividades)
"""
# Out:
# '\nFT = Full Time (Horário Integral, comercial aqui no Brasil)\nCT = Contato Trabalho por determinado período de tempo\nPT = Parcial Time (Meio Período)\nFL = FreeLance (Trabalho por projetos ou em deteminadas atividades)\n'

# %%
df["remoto"].value_counts()
# Legenda/Total tipo de trabalho 0 = Presencial | 100 = Remoto | 50 = Híbrido
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Legenda Tamanho Empresa M = Medium (Médio) | L = Large (Grande) | S = Small (Pequeno)
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
# Legenda de Senioridades SE = Senior | MI = Pleno | EN = Junior | EX = Executivo(CEO Level)
senioridade_traducao = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}

df['senioridade'] = df['senioridade'].replace(senioridade_traducao)
#df['senioridade'] = df['senioridade'].map(senioridade_traducao)
# REPLACE - foi usado para substituir valores específicos na coluna 'senioridade'.
#   Ele procurou pelas abreviações ('SE', 'MI', etc.) e trocou cada uma pelo seu valor correspondente
#   no dicionário senioridade_traducao ('Senior', 'Pleno', etc.). É bom para trocar alguns valores por outros.
# MAP - (nesse contexto específico) também poderia ter sido usado para fazer a mesma troca,
#   aplicando o dicionário a cada item da coluna. A principal diferença é que map é mais focado em transformar cada elemento
#   de uma série com base em um mapeamento, e se um valor não for encontrado no dicionário, ele colocaria NaN (valor ausente)
#   por padrão, a menos que você especifique o contrário. replace é mais flexível para diferentes tipos de substituição.

df["senioridade"].value_counts()
# Out:
# senioridade
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
# Tipo de Contrato de Trabalho ["tipo_emprego"]
# FT = Full Time (Horário Integral, comercial aqui no Brasil)
# CT = Contato Trabalho por determinado período de tempo
# PT = Parcial Time (Meio Período)
# FL = FreeLance (Trabalho por projetos ou em deteminadas atividades)
contrato_traducao = {
    'FT': 'Integral',
    'CT': 'Contrato',
    'PT': 'Parcial',
    'FL': 'Freelance'
}

df['contrato'] = df['contrato'].replace(contrato_traducao)

df["contrato"].value_counts()
# Out:
# contrato
# Integral     132563
# Contrato        394
# Parcial         376
# Freelance        16
# Name: count, dtype: int64

# %%
# Legenda/Total tipo de trabalho 0 = Presencial | 100 = Remoto | 50 = Híbrido
remoto_traducao = {
    0: 'Presencial',
    100: 'Remoto',
    50: 'Hibrido'
}

df['remoto'] = df['remoto'].replace(remoto_traducao)

df["remoto"].value_counts()
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Hibrido          319
# Name: count, dtype: int64

# %%
# Legenda Tamanho Empresa M = Medium (Médio) | L = Large (Grande) | S = Small (Pequeno)
tamanho_empresa_traducao = {
    'M': 'Media',
    'L': 'Grande',
    'S': 'Pequena'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa_traducao)

df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# Media      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      Senior  Integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      Senior  Integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       Pleno  Integral       Data Engineer   158800   USD  158800
# 3  2025.0       Pleno  Integral       Data Engineer   139200   USD  139200
# 4  2025.0      Junior  Integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      Remoto      US           Media
# 1         US      Remoto      US           Media
# 2         AU  Presencial      AU           Media
# 3         AU  Presencial      AU           Media
# 4         US  Presencial      US           Media

# %%
df.describe(include='object')
# Out:
#        senioridade  contrato           cargo   moeda residencia      remoto  \
# count       133349    133349          133349  133349     133349      133349
# unique           4         4             390      26        102           3
# top         Senior  Integral  Data Scientist     USD         US  Presencial
# freq         77241    132563           17314  126140     119579      105312
#
#        empresa tamanho_empresa
# count   133349          133349
# unique      95               3
# top         US           Media
# freq    119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %% [markdown]
# ## Aula 02 - Tratamento de Dados

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.isnull().sum()
# Verificar e tratar dados nulos no DataFrame df
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade  contrato                      cargo  salario moeda  \
# 5588    NaN      Senior  Integral            Product Manager   184500   USD
# 59692   NaN       Pleno  Integral                   Engineer   110000   USD
# 59710   NaN      Junior  Integral             Data Scientist   208800   USD
# 59759   NaN      Senior  Integral          Software Engineer   135000   USD
# 59789   NaN      Senior  Integral                   Engineer   112000   USD
# 131000  NaN      Senior  Integral  Machine Learning Engineer   163800   USD
# 131006  NaN      Senior  Integral     Data Analytics Manager   204500   USD
# 133054  NaN      Junior  Integral             Data Scientist    40000   USD
# 133281  NaN       Pleno  Integral  Machine Learning Engineer   180000   PLN
# 133317  NaN       Pleno  Integral             Data Scientist   130000   USD
#
#            usd residencia      remoto empresa tamanho_empresa
# 5588    184500         US  Presencial      US           Media
# ...

# %%
df_salarios = pd.DataFrame(df, columns=['salario', 'usd'])
df_salarios.head()
# Out:
#    salario     usd
# 0   214000  214000
# 1   136000  136000
# 2   158800  158800
# 3   139200  139200
# 4    90000   90000

# %%
import numpy as np

df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "val"],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})

# Médias Salariais para:

# Média - é o valor central (soma/quantidade)
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
#display(df_salarios)

# Mediana - é o valor do meio em dados ordenados
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())#.round(2))
#display(df_salarios)

# Moda - é o valor que mais se repete - (foi pego o primeiro valor pois pode retornar múltiplos valores)
df_salarios['salario_moda'] = df_salarios['salario'].fillna(df_salarios['salario'].mode()[0].round(2))
display(df_salarios)
# Out:
#       nome   salario  salario_media  salario_mediana  salario_moda
# 0      Ana    4000.0        4000.00           4000.0        4000.0
# 1    Bruno       NaN       36333.33           5000.0        4000.0
# 2   Carlos    5000.0        5000.00           5000.0        5000.0
# 3  Daniele       NaN       36333.33           5000.0        4000.0
# 4      val  100000.0      100000.00         100000.0      100000.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, 28, np.nan, 33]
})

df_temperaturas["Preenchido_ffill"] = df_temperaturas["Temperatura"].ffill()
df_temperaturas
# Out:
#        Dia  Temperatura  Preenchido_ffill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              30.0
# 2   Quarta         28.0              28.0
# 3   Quinta          NaN              28.0
# 4    Sexta         33.0              33.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [np.nan, np.nan, 28, np.nan, 33]
})

df_temperaturas["Preenchido_bfill"] = df_temperaturas["Temperatura"].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  Preenchido_bfill
# 0  Segunda          NaN              28.0
# 1    Terça          NaN              28.0
# 2   Quarta         28.0              28.0
# 3   Quinta          NaN              33.0
# 4    Sexta         33.0              33.0

# %%
df_cidades = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "val"],
    'cidade': ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})

#df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna(df_cidades['cidade'].mode()[0]) #Aqui vai repetir a última cidade Belém para todos os 'NaN'
df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna("Não Informado") #Aqui vai substituir todos os 'NaN' por 'Não Informado'
display(df_cidades)
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não Informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não Informado
# 4      val      Belém             Belém

# %%
df_limpo = df.dropna()
df_limpo.isnull().sum()
#df_limpo.head()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      Senior  Integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      Senior  Integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       Pleno  Integral       Data Engineer   158800   USD  158800
# 3  2025.0       Pleno  Integral       Data Engineer   139200   USD  139200
# 4  2025.0      Junior  Integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      Remoto      US           Media
# 1         US      Remoto      US           Media
# 2         AU  Presencial      AU           Media
# 3         AU  Presencial      AU           Media
# 4         US  Presencial      US           Media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
# Atribuindo tipo de Dados Convertendo o ano 'object' para 'int64'

df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %% [markdown]
# ## Aula 03 - Imprimindo Análise e Gráficos com MatProtLib

# %% [markdown]
# Criando gráficos dos dados para fins estatísticos para explorar e demonstrar informações com uso de Histogramas, Boxplots, Barras, etc.

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      Senior  Integral  Solutions Engineer   214000   USD  214000
# 1  2025      Senior  Integral  Solutions Engineer   136000   USD  136000
# 2  2025       Pleno  Integral       Data Engineer   158800   USD  158800
# 3  2025       Pleno  Integral       Data Engineer   139200   USD  139200
# 4  2025      Junior  Integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      Remoto      US           Media
# 1         US      Remoto      US           Media
# 2         AU  Presencial      AU           Media
# 3         AU  Presencial      AU           Media
# 4         US  Presencial      US           Media

# %%
df_limpo['senioridade'].value_counts()
# Out:
# senioridade
# Senior       77236
# Pleno        40462
# Junior       12441
# Executivo     3200
# Name: count, dtype: int64

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar', title='Distribuição de Senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de Senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(data=df_limpo, x='senioridade', y='salario', hue='contrato')
# Out:
# <Axes: xlabel='senioridade', ylabel='salario'>

# %%
sns.barplot(data=df_limpo, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
plt.figure(figsize=(8, 10))
sns.barplot(data=df_limpo, x='senioridade', y='usd')
plt.title('Salário Médio por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual - USD')
plt.show()

# %%
df_limpo.groupby('senioridade')['usd'].mean().plot(kind='bar', title='Salário Médio por Senioridade')
# Out:
# <Axes: title={'center': 'Salário Médio por Senioridade'}, xlabel='senioridade'>

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index

# %%
ordem
# Out:
# Index(['Executivo', 'Senior', 'Pleno', 'Junior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem)
plt.title('Salário Médio por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual - USD')
plt.show()

# %%
ordem_asc = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index
ordem_senioridade = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index
ordem_asc
# Out:
# Index(['Junior', 'Pleno', 'Senior', 'Executivo'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem_asc)
plt.title('Salário Médio por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual - USD')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df_limpo['usd'], bins=50, kde=True)
plt.title('Distribuição dos Salários Anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df_limpo['usd'])
plt.title('Bloxplot - Distribuição dos Salários Anuais')
plt.xlabel('Salário em USD')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title('Bloxplot - Distribuição dos Salários Anuais')
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']

plt.figure(figsize=(10, 5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette="Set2", hue='senioridade', legend=False)
plt.title('Bloxplot - Distribuição dos Salários Anuais')
plt.xlabel('Salário em USD')
plt.show()

# %%
import plotly.express as px

# Cálcula a média salarial por senioridade
salario_medio_senioridade = df_limpo.groupby('senioridade')['usd'].mean().reset_index()

ordem_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']

# Cria o gráfico em barras usando o Plotly Express = 'px'
fig = px.bar(salario_medio_senioridade,
             x='senioridade',
             y='usd',
             title='Salário Médio por Senioridade',
             labels={'senioridade': 'Senioridade', 'usd': 'Salário Médio Anual (USD)'},
             category_orders={'senioridade': ordem_senioridade})

# Imprime o Gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Gráfico Pizza Profissionais por Modalidade de Trabalho

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

# Cria o gráfico de pizzas usando o Plotly Express = 'px'
fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Profissionais por Modalidade de Trabalho')

# Imprime o Gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Gráfico Pizza Profissionais por Modalidade de Trabalho

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

# Cria o gráfico de pizzas usando o Plotly Express = 'px'
fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Profissionais por Modalidade de Trabalho',
             hole=0.5)

# Imprime o Gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Gráfico Pizza Profissionais por Modalidade de Trabalho

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

# Cria o gráfico de pizzas usando o Plotly Express = 'px'
fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Profissionais por Modalidade de Trabalho',
             hole=0.5)

# Imprime o Gráfico
#fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 14.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Aula 04 - Criando Dashboard no VSCode com a StreamLit

# %%
# pip install pycountry # para fazer conversão de sigla de país para sigla/código de cada país
# Exemplo:
# O código ISO-3 de 'br' é: BRA
# O código ISO-3 de 'US' é: USA
# O código ISO-3 de 'XX' é: None

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3 conforme a sigla do pais
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#df_limpo['cargo'].unique()
cargos_unicos = df_limpo['cargo'].unique()
cargos_ordenados = sorted(cargos_unicos)
print(cargos_ordenados)
# Out:
# ['AI Architect', 'AI Content Writer', 'AI Data Engineer', 'AI Data Scientist', 'AI Developer', 'AI Engineer', 'AI Engineering Lead', 'AI Engineering Manager', 'AI Governance Lead', 'AI Governance Specialist', 'AI Lead', 'AI Machine Learning Engineer', 'AI Product Lead', 'AI Product Manager', 'AI Product Owner', 'AI Programmer', 'AI Research Engineer', 'AI Research Scientist', 'AI Researcher', 'AI Scientist', 'AI Software Development Engineer', 'AI Software Engineer', 'AI Solution Architect', 'AI Solutions Specialist', 'AI Specialist', 'AI Strategist', 'AI Tech Lead', 'AWS Data Architect', 'Account Executive', 'Actuarial Analyst', 'Actuary', 'Admin & Data Analyst', 'Advanced Data Analyst', 'Algorithm Developer', 'Alternance', 'Analyst', 'Analytics Analyst', 'Analytics Engineer', 'Analytics Engineering Manager', 'Analytics Lead', 'Analytics Specialist', 'Application Developer', 'Applied AI ML Lead', 'Applied Data Scientist', 'Applied Machine Learning Engineer', 'Applied Machine Learnin
# ...

# %%
# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Engineer']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Engenheiro de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head() # verificando nova coluna residencia_iso3
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      Senior  Integral  Solutions Engineer   214000   USD  214000
# 1  2025      Senior  Integral  Solutions Engineer   136000   USD  136000
# 2  2025       Pleno  Integral       Data Engineer   158800   USD  158800
# 3  2025       Pleno  Integral       Data Engineer   139200   USD  139200
# 4  2025      Junior  Integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa residencia_iso3
# 0         US      Remoto      US           Media             USA
# 1         US      Remoto      US           Media             USA
# 2         AU  Presencial      AU           Media             AUS
# 3         AU  Presencial      AU           Media             AUS
# 4         US  Presencial      US           Media             USA

# %%
#importa o CSV abaixo para a pasta padrão do Google colab depois eu posso salvar na minha máquina ou em outro local
df_limpo.to_csv('dados-imersao-python-final-2025.csv', index=False)
